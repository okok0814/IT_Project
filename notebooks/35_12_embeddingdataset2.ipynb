# %%
pip install ftfy regex tqdm git+https://github.com/openai/CLIP.git transformers pandas pillow
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-pisdeob8
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-pisdeob8
#   Resolved https://github.com/openai/CLIP.git to commit d05afc436d78f1c48dc0dbf8e5980a9d471f35f6
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.5 MB/s eta 0:00:00
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=5516399e6d04728cfed81120ed7d6de0f7f3efa7650ab389babb911c8d91c8ab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bs6uyf93/wheels/cb/a8/74/5f32d6cf0407457f0f62737b6da5c14eb86b9cac476fdf630d
# Successfully built clip
# ...

# %%
# !git clone https://github.com/okok0814/IT_Project.git
# %cd IT_Project
# Out:
# Cloning into 'IT_Project'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 93 (delta 22), reused 80 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (93/93), 5.87 MiB | 24.25 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# /content/IT_Project

# %%
import os

os.environ["KAGGLE_API_TOKEN"] = "KGAT_01d64b7240c4cddf0a5e24709928d9da"

# !mkdir -p ./data/dataset2

print("Downloading Fashion Product Images Dataset from Kaggle...")
# !kaggle datasets download paramaggarwal/fashion-product-images-small -p ./data

print("Unzipping dataset...")
# !unzip -q -o ./data/fashion-product-images-small.zip -d ./data/dataset2

print("Extraction complete. Checking contents of ./data/dataset2:")
# !ls -la ./data/dataset2
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/paramaggarwal/fashion-product-images-small
# License(s): MIT
# ...
# 100% 565M/565M [00:30<00:00, 19.5MB/s]
#
# Unzipping dataset...
# Extraction complete. Checking contents of ./data/dataset2:
# total 5392
# drwxr-xr-x 4 root root    4096 Sep  8 07:07 .
# drwxr-xr-x 4 root root    4096 Sep  8 07:07 ..
# drwxr-xr-x 2 root root 1175552 Sep  8 07:07 images
# drwxr-xr-x 3 root root    4096 Sep  8 07:07 myntradataset
# -rw-r--r-- 1 root root 4332000 Oct 22  2019 styles.csv

# %%
# Chạy kiểm thử hệ thống
# !python scripts/embed_dataset2.py --self_test
print("\n--------------------------------------------------\n")

# Chạy trích xuất thực tế
# !python scripts/embed_dataset2.py
# Out:
# device = cuda
# 36 sản phẩm có ảnh hợp lệ (đã loại 1 ID thiếu ảnh)
# CLIP: 100% 1/1 [00:00<00:00, 689.40it/s]
# [CLIP] 36 sản phẩm trong 0.0s (0.1 ms/sản phẩm)
# FashionCLIP: 100% 1/1 [00:00<00:00, 873.09it/s]
# [FashionCLIP] 36 sản phẩm trong 0.0s (0.0 ms/sản phẩm)
# [SELF-TEST PASSED] batching + ghép nối + shape đều đúng với 36 sản phẩm (đã loại 1 ID thiếu ảnh), batch lẻ không chia hết.
#
# --------------------------------------------------
#
# device = cuda
# 44419 sản phẩm có ảnh hợp lệ (đã loại 5 ID thiếu ảnh)
# CLIP: 100% 695/695 [03:13<00:00,  3.60it/s]
# [CLIP] 44419 sản phẩm trong 193.1s (4.3 ms/sản phẩm)
# ...
# Loading weights: 100% 398/398 [00:00<00:00, 4598.76it/s]
# FashionCLIP: 100% 695/695 [04:08<00:00,  2.80it/s]
# [FashionCLIP] 44419 sản phẩm trong 248.6s (5.6 ms/sản phẩm)
# Xong. File đã lưu trong ./embeddings
