# %%
# !git clone https://github.com/okok0814/IT_Project.git
# %cd IT_Project
# Out:
# Cloning into 'IT_Project'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 58 (delta 9), reused 51 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 2.82 MiB | 31.71 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/IT_Project

# %%
import os

os.environ["KAGGLE_API_TOKEN"] = "KGAT_01d64b7240c4cddf0a5e24709928d9da"

# !mkdir -p ./data/dataset2

print("Downloading Fashion Product Images Dataset from Kaggle...")
# !kaggle datasets download paramaggarwal/fashion-product-images-small -p ./data

print("Unzipping dataset...")
# !unzip -q -o ./data/fashion-product-images-small.zip -d ./data/dataset2

print("Extraction complete. Checking contents of ./data/dataset2:")
# !ls -la ./data/dataset2
# Out:
# Downloading Fashion Product Images Dataset from Kaggle...
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/paramaggarwal/fashion-product-images-small
# License(s): MIT
# Downloading fashion-product-images-small.zip to ./data
# 100% 565M/565M [00:28<00:00, 21.1MB/s]
#
# Unzipping dataset...
# Extraction complete. Checking contents of ./data/dataset2:
# total 5412
# drwxr-xr-x 4 root root    4096 Aug 25 10:10 .
# drwxr-xr-x 4 root root    4096 Aug 25 10:09 ..
# drwxr-xr-x 2 root root 1196032 Aug 25 10:09 images
# drwxr-xr-x 3 root root    4096 Aug 25 10:10 myntradataset
# -rw-r--r-- 1 root root 4332000 Oct 22  2019 styles.csv

# %%
# Chạy self-test trước để đảm bảo script không bị lỗi
# !python scripts/dataset2_organize_check.py --self_test

print("\n--------------------------------------------------\n")

# Chạy kiểm tra trên dataset thật
# !python scripts/dataset2_organize_check.py --data_dir ./data/dataset2
# Out:
# [SELF-TEST] Tạo dữ liệu giả lập (12 sản phẩm: 2 thiếu ảnh, 1 orphan, 1 hỏng)...
# [SELF-TEST] Kết quả (kỳ vọng: missing=2, orphan=1, corrupt=1):
#   rows_loaded_from_csv: 12
#   missing_expected_columns: []
#   unique_ids_in_csv: 12
#   image_files_on_disk: 11
#   ids_in_csv_missing_image_file: 2
#   image_files_with_no_csv_row: 1
#   images_checked_for_corruption: 10
#   corrupt_images_found: 1
#   corrupt_image_ids_sample: ['1002']
#   category_distribution: {'Apparel': 12}
#   gender_distribution: {'Men': 6, 'Women': 6}
#
# --------------------------------------------------
#
# === Dataset 2 — báo cáo tổ chức & kiểm tra toàn vẹn (DỮ LIỆU THẬT) ===
#   rows_loaded_from_csv: 44424
#   missing_expected_columns: []
#   unique_ids_in_csv: 44424
#   image_files_on_disk: 44441
#   ids_in_csv_missing_image_file: 5
#   image_files_with_no_csv_row: 22
#   images_checked_for_corruption: 2000
#   corrupt_images_found: 0
#   corrupt_image_ids_sample: []
#   category_distribution: {'Apparel': 21397, 'Accessories': 11274, 'Footwear': 9219, 'Personal Care': 2403, 'Free Items': 105, 'Sporting Goods': 25, 'Home': 1}
#   gender_distribution: {'Men': 22147, 'Women': 18631, 'Unisex': 2161, 'Boys': 830, 'Girls': 655}
