# %%
# !git clone https://github.com/okok0814/IT_Project.git
# %cd IT_Project
# !pip install ftfy regex tqdm git+https://github.com/openai/CLIP.git transformers matplotlib pandas pillow
# Out:
# /content/IT_Project

# %%
# !kaggle datasets download paramaggarwal/fashion-product-images-small -p ./data
# !unzip -q -o ./data/fashion-product-images-small.zip -d ./data/dataset2
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/paramaggarwal/fashion-product-images-small
# License(s): MIT
# ...
# 100% 565M/565M [00:02<00:00, 213MB/s]

# %%
import sys
sys.path.append("/content/IT_Project/scripts")
from compare_backbones import load_embeddings, retrieve_all, judge_blind, compute_precision_at_5, QUERY_SET

assert len(QUERY_SET) >= 15
data = load_embeddings()
results = retrieve_all(QUERY_SET, data)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ...

# %%
judgments = judge_blind(results)
# Out:
# Ảnh nào LIÊN QUAN đến 'red running shoes'? (vd: A,C,E — Enter nếu không có): A,B,C,D,E,F,G
# Ảnh nào LIÊN QUAN đến 'giày chạy bộ màu đỏ'? (vd: A,C,E — Enter nếu không có):
# Ảnh nào LIÊN QUAN đến 'black leather handbag'? (vd: A,C,E — Enter nếu không có): A,B,C,D,E,F,G,H
# Ảnh nào LIÊN QUAN đến 'túi xách da màu đen'? (vd: A,C,E — Enter nếu không có): F
# Ảnh nào LIÊN QUAN đến 'a white collared shirt for office wear'? (vd: A,C,E — Enter nếu không có): A,B,C,D,E,F,G,H,I
# Ảnh nào LIÊN QUAN đến 'áo sơ mi trắng công sở'? (vd: A,C,E — Enter nếu không có): H
# Ảnh nào LIÊN QUAN đến 'high waisted wide leg linen pants'? (vd: A,C,E — Enter nếu không có): A,B,C,D,E,F,G,H,I,J
# Ảnh nào LIÊN QUAN đến 'quần ống rộng lưng cao vải linen'? (vd: A,C,E — Enter nếu không có): F,G,H,I,J
# Ảnh nào LIÊN QUAN đến 'waterproof winter coat with faux fur hood'? (vd: A,C,E — Enter nếu không có): B,C,E,F,G,H
# ...

# %%
df, summary = compute_precision_at_5(results, judgments)
df.to_csv("./logs/backbone_comparison_results.csv", index=False)
print(df)
print(summary)
# Out:
#                                                 query        model  \
# 0                                   red running shoes         clip
# 1                                   red running shoes  fashionclip
# 2                                 giày chạy bộ màu đỏ         clip
# 3                                 giày chạy bộ màu đỏ  fashionclip
# 4                               black leather handbag         clip
# 5                               black leather handbag  fashionclip
# 6                                 túi xách da màu đen         clip
# 7                                 túi xách da màu đen  fashionclip
# 8              a white collared shirt for office wear         clip
# 9              a white collared shirt for office wear  fashionclip
# 10                             áo sơ mi trắng công sở         clip
# 11                             áo sơ mi trắng công sở  fashionclip
# 12                  high waisted wide leg linen pants         clip
# ...
