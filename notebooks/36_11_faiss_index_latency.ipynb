# %%
# !git clone https://github.com/okok0814/IT_Project.git
# %cd IT_Project
# Out:
# Cloning into 'IT_Project'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 103 (delta 26), reused 87 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (103/103), 5.91 MiB | 33.81 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# /content/IT_Project

# %%
# !pip install faiss-gpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.2/135.2 MB 7.3 MB/s eta 0:00:00
# ...

# %%
# !python scripts/faiss_index_and_latency.py --self_test

print("\n--------------------------------------------------\n")

# !python scripts/faiss_index_and_latency.py
# Out:
# [SELF-TEST] Tạo 2000 vector ngẫu nhiên 512 chiều (KHÔNG PHẢI embedding thật)...
# Đang tải: /tmp/fake_embeddings.npy
# Shape: (2000, 512)
#
# --- IndexFlatIP (brute-force, đúng 100%) ---
# mean=0.213ms  p95=0.260ms  (k=10, 100 lần)
# [Đã lưu] Flat Index tại: ./embeddings/fake_embeddings_flat.index
#
# [Điều chỉnh nlist] 2000 vector không đủ cho nlist=100 (cần ~3900) — giảm nlist xuống 50 cho hợp quy mô.
#
# --- IndexIVFFlat (approximate) ---
# mean=0.054ms  p95=0.076ms
# [Đã lưu] IVF Index tại: ./embeddings/fake_embeddings_ivf.index
#
# Độ trùng khớp top-10 giữa IVF và Flat: 41.5%
#
# [SELF-TEST PASSED] Toàn bộ pipeline load->normalize->index->search chạy đúng logic.
#
# --------------------------------------------------
#
#
#
# ...
# BẮT ĐẦU ĐÁNH GIÁ: clip_image_embeddings.npy
# ...
# Đang tải: ./embeddings/clip_image_embeddings.npy
# Shape: (44419, 512)
#
# --- IndexFlatIP (brute-force, đúng 100%) ---
# mean=14.607ms  p95=16.263ms  (k=10, 100 lần)
# ...
